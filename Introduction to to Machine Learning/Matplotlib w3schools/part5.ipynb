# %%
import matplotlib.pyplot as plt

# داده‌ها
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

# رسم نمودار با Marker بزرگ
plt.plot(x, y, marker='D', markersize=15)  # Marker با اندازه ۱۵

# نمایش نمودار
plt.show()
